# %%
# Creating my first machine learing model for predicting the price estimate of a house

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
#Creating a reproducible synthetic dataset
np.random.seed(42)
number_of_houses = 200

square_feet = np.random.randint(
    700, 3501, number_of_houses
).astype(float)
bedrooms = np.random.randint(
    1, 6, number_of_houses
).astype(float)
age = np.random.randint(
    0, 61, number_of_houses
).astype(float)
noise = np.random.normal(
    0, 25000, number_of_houses
).astype(float)

# %%
#Create synthetic house prices

price = (
    10000000
    + 500000 * square_feet
    + 500000 * bedrooms
    - 2000000 * age
    + noise
)

# %%
# Organize the data inot a table
house = pd.DataFrame({
    "square_feet": square_feet,
    "bedrooms": bedrooms,
    "age": age,
    "price": price.round(2)
})

# %%
# Separate the features from the target
X = house[["square_feet", "bedrooms", "age"]]
Y = house["price"]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    X,
    Y,
    test_size= 0.20,
    random_state= 42
)

# %%
# Create and train the model
model = LinearRegression()
model.fit(X_train, Y_train)
predictions = model.predict(X_test)
print(predictions)
# Out:
# [1.02200303e+09 1.11000265e+09 8.41500943e+08 1.01050206e+09
#  5.17006129e+08 1.33350037e+09 1.32100079e+09 1.57999296e+09
#  7.00502080e+08 1.32849663e+09 1.14499974e+09 1.26949567e+09
#  1.36300005e+09 5.07007611e+08 1.21999883e+09 6.60002371e+08
#  1.42799713e+09 1.63999422e+09 1.42999578e+09 4.16005627e+08
#  8.19502220e+08 1.53499896e+09 1.15000071e+09 1.35649924e+09
#  1.66249374e+09 1.55299847e+09 1.35800007e+09 4.11008373e+08
#  5.02005931e+08 1.08550018e+09 1.01450045e+09 7.31002717e+08
#  2.75509170e+08 8.18499616e+08 1.57849440e+09 1.16050182e+09
#  5.96505439e+08 3.12008893e+08 1.08500147e+09 1.49399932e+09]

# %%
# Compare several predictions with the actual price
results = pd.DataFrame({
    "actual_price": Y_test.values,
    "predicted_price": predictions.round(2)
})

print("\nACTUAL VS. PREDICTED PRICES")
print(results.head(10))
# Out:
# ACTUAL VS. PREDICTED PRICES
#    actual_price  predicted_price
# 0  1.022036e+09     1.022003e+09
# 1  1.110034e+09     1.110003e+09
# 2  8.415017e+08     8.415009e+08
# 3  1.010505e+09     1.010502e+09
# 4  5.169975e+08     5.170061e+08
# 5  1.333512e+09     1.333500e+09
# 6  1.321008e+09     1.321001e+09
# 7  1.580035e+09     1.579993e+09
# 8  7.005007e+08     7.005021e+08
# 9  1.328466e+09     1.328497e+09

# %%
#Predict the price of a new house
new_house = pd.DataFrame({
    "square_feet": [500],
    "bedrooms": [3],
    "age": [11]
})

predicted_price = model.predict(new_house)
print(predicted_price)
# Out:
# [2.39507208e+08]
