# %%
# Creating my first machine learing model for predicting the price estimate of a house

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
#Creating a reproducible synthetic dataset
np.random.seed(42)
number_of_houses = 200

square_feet = np.random.randint(
    700, 3501, number_of_houses
).astype(float)
bedrooms = np.random.randint(
    1, 6, number_of_houses
).astype(float)
age = np.random.randint(
    0, 61, number_of_houses
).astype(float)
noise = np.random.normal(
    0, 25000, number_of_houses
).astype(float)

# %%
#Create synthetic house prices

price = (
    1000000
    + 100000 * square_feet
    + 5000000 * bedrooms
    - 1000000 * age
    + noise
)

# %%
# Organize the data inot a table
house = pd.DataFrame({
    "square_feet": square_feet,
    "bedrooms": bedrooms,
    "age": age,
    "price": price.round(2)
})

# %%
# Separate the features from the target
X = house[["square_feet", "bedrooms", "age"]]
Y = house["price"]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    X,
    Y,
    test_size= 0.20,
    random_state= 42
)

# %%
# Create and train the model
model = LinearRegression()
model.fit(X_train, Y_train)
predictions = model.predict(X_test)
print(predictions)
# Out:
# [1.82503026e+08 2.23502653e+08 1.84500943e+08 2.01302055e+08
#  1.00206129e+08 2.40600367e+08 2.59100794e+08 3.03492959e+08
#  1.53902080e+08 2.65096628e+08 2.40899740e+08 2.49795675e+08
#  2.41700047e+08 9.87076106e+07 2.37298829e+08 1.42802371e+08
#  2.81297133e+08 3.39394218e+08 2.85395783e+08 8.31056269e+07
#  1.60802220e+08 2.98298956e+08 2.17200709e+08 2.74699238e+08
#  3.24693736e+08 2.80298474e+08 2.39500070e+08 7.71083733e+07
#  7.62059306e+07 2.25400180e+08 1.90200448e+08 1.27502717e+08
#  2.84091695e+07 1.71599616e+08 3.05494398e+08 2.06601817e+08
#  1.14305439e+08 3.75088932e+07 2.18601472e+08 2.91299316e+08]

# %%
# Compare several predictions with the actual price
results = pd.DataFrame({
    "actual_price": Y_test.values,
    "predicted_price": predictions.round(2)
})

print("\nACTUAL VS. PREDICTED PRICES")
print(results.head(10))
# Out:
# ACTUAL VS. PREDICTED PRICES
#    actual_price  predicted_price
# 0  1.825361e+08     1.825030e+08
# 1  2.235340e+08     2.235027e+08
# 2  1.845017e+08     1.845009e+08
# 3  2.013055e+08     2.013021e+08
# 4  1.001975e+08     1.002061e+08
# 5  2.406122e+08     2.406004e+08
# 6  2.591076e+08     2.591008e+08
# 7  3.035349e+08     3.034930e+08
# 8  1.539007e+08     1.539021e+08
# 9  2.650661e+08     2.650966e+08

# %%
#Predict the price of a new house
new_house = pd.DataFrame({
    "square_feet": [500],
    "bedrooms": [5],
    "age": [0]
})

predicted_price = model.predict(new_house)
print(predicted_price)
# Out:
# [76004486.82120064]
